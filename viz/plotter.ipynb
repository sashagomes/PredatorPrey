# %%
# import numpy as np
# import matplotlib.pyplot as plt
import pandas as pd

# %%
table = pd.read_csv("../simout/0.txt")
table
# Out:
#     timestep  iswolf  id  posx  posy   age     color  hunger    vision
# 0          0       1   0     1     1   0.0       NaN     0.0  0.934829
# 1          0       1   1     1     2   0.0       NaN     0.0  0.917510
# 2          0       0   2     0     0   0.0  0.356553     NaN       NaN
# 3          0       0   3     1     0   0.0  0.798445     NaN       NaN
# 4          1       1   0     2     0   2.5       NaN     8.5  0.934829
# 5          1       1   1     1     3   2.5       NaN     8.5  0.917510
# 6          1       0   2    -1     1   2.5  0.356553     NaN       NaN
# 7          1       0   3     2     1   2.5  0.798445     NaN       NaN
# 8          2       1   0     3     1   5.0       NaN    17.0  0.934829
# 9          2       1   1     2     2   5.0       NaN    17.0  0.917510
# 10         2       0   2    -1     2   5.0  0.356553     NaN       NaN
# 11         2       0   3     2     0   5.0  0.798445     NaN       NaN
# ...
